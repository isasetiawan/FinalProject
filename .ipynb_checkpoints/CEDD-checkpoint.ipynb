# %%
from scipy import ndimage
import matplotlib.pyplot as plt

image = ndimage.imread('dataset/0280.jpeg')
print image.shape

for i in range(3):
    plt.imshow(image[:, :, i])
    plt.show()
# Out:
# (506L, 768L, 3L)
